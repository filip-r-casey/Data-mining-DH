# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
data = pd.read_csv('Final_MLB_Data.csv')
data.groupby('Name').Team.count().sort_values(ascending=False).head(10)
# Out:
# Name
# Yu Chang             4
# Mike Ford*           4
# Steven Duggar*       3
# Bradley Zimmer*      3
# Andrew Knapp#        3
# Oscar Mercado        3
# Stuart Fairchild     3
# Kevin Padlo          3
# Sergio Alcantara#    3
# Austin Romine        3
# Name: Team, dtype: int64

# %%
data[data.Name == 'Yu Chang']
# Out:
#          Name  Age Team  Lg   G   PA  AB   R   H  2B  ...  GDP  HBP  SH  SF  \
# 161  Yu Chang   26  CLE  AL   4   10  10   0   0   0  ...    0    0   0   0
# 162  Yu Chang   26  PIT  NL  18   49  42   5   7   1  ...    1    3   0   0
# 163  Yu Chang   26  TBR  AL  36  105  96  11  25   3  ...    3    0   0   2
# 164  Yu Chang   26  BOS  AL  11   26  20   3   3   2  ...    1    1   0   0
#
#      IBB      wOBA       OAA       OFF       DEF  Qualified DH
# 161    0  0.000000  0.463768  0.000000  0.463768            No
# 162    0  0.260000  2.086957  0.260000  2.086957            No
# 163    0  0.303333  4.173913  0.303333  4.173913            No
# 164    0  0.292308  1.275362  0.292308  1.275362            No
#
# [4 rows x 33 columns]

# %%
data.sort_values('OFF', ascending=False).head(10)
# Out:
#                 Name  Age Team  Lg    G   PA   AB    R    H  2B  ...  GDP  \
# 443      Khalil Lee*   24  NYM  NL    2    2    2    1    1   0  ...    0
# 812   Chadwick Tromp   27  ATL  NL    1    4    4    0    3   2  ...    0
# 629    Evan Phillips   27  LAD  NL    1    1    0    0    0   0  ...    0
# 462       Otto Lopez   23  TOR  AL    8   10    9    0    6   0  ...    0
# 592    James Outman*   25  LAD  NL    4   16   13    6    6   2  ...    0
# 147  Matt Carpenter*   36  NYY  AL   47  154  128   28   39   9  ...    2
# 405      Aaron Judge   30  NYY  AL  157  696  570  133  177  28  ...   14
# 236       Joe Dunand   26  MIA  NL    3   11   10    2    3   1  ...    0
# 359    David Hensley   26  HOU  AL   16   34   29    7   10   2  ...    3
# 331   Dalton Guthrie   26  PHI  NL   14   28   21    3    7   0  ...    0
#
#      HBP  SH  SF  IBB      wOBA  OAA       OFF  DEF  Qualified DH
# 443    0   0   0    0  1.050000  0.0  1.050000  0.0            No
# ...

# %%
data.sort_values('DEF', ascending=False).head(10)
# Out:
#                     Name  Age Team  Lg    G   PA   AB   R    H  2B  ...  GDP  \
# 776          Myles Straw   27  CLE  AL  152  596  535  72  118  22  ...    4
# 640           AJ Pollock   34  CHW  AL  138  527  489  61  120  26  ...   13
# 106  Jackie Bradley Jr.*   32  BOS  AL   91  290  271  21   57  19  ...    3
# 416         Ha-Seong Kim   26  SDP  NL  150  582  517  58  130  29  ...    9
# 111         Alex Bregman   28  HOU  AL  155  656  548  93  142  38  ...   18
# 274        Adam Frazier*   30  SEA  AL  156  602  541  61  129  22  ...   15
# 24            Nick Allen   23  OAK  AL  100  326  299  31   62  13  ...    5
# 595       Cristian Pache   23  OAK  AL   91  260  241  18   40   5  ...    5
# 530      Whit Merrifield   33  KCR  AL   95  420  383  51   92  23  ...    8
# 341      Garrett Hampson   27  COL  NL   90  226  199  29   42   7  ...    3
#
#      HBP  SH  SF  IBB      wOBA        OAA       OFF        DEF  Qualified DH
# ...

# %%
player_off_hist = px.histogram(data, x='OFF', nbins=50, title='Offensive Score Distribution', height=700, width=1000)
player_off_hist.show()

player_def_hist = px.histogram(data, x='DEF', nbins=50, title='Defensive Score Distribution', height=700, width=1000)
player_def_hist.show()

# %%
player = data[['Name','Team','OFF','DEF','Qualified DH']].copy()
player['Total Value'] = player.OFF + player.DEF
# player.sort_values('Total Value', ascending=False).head(10)
player_val_hist = px.histogram(player, x='Total Value', nbins=50, title='Total Value Distribution', color='Qualified DH', height=700, width=1000, barmode='overlay', opacity=0.7)
player_val_hist.show()

# %%
player['is_full_DH'] = player['Qualified DH'].apply(lambda x: 1 if x == 'Yes' else 0)
team_df = player.groupby('Team').agg({'OFF':'sum', 'DEF':'sum', 'Total Value':'sum', 'is_full_DH':'max'}).reset_index()
team_df.sort_values('Total Value', ascending=False)
# Out:
#    Team       OFF        DEF  Total Value  is_full_DH
# 19  OAK  7.809116  21.463817    29.272934           0
# 26  TBR  6.899890  19.705294    26.605184           0
# 28  TOR  6.771664  19.633089    26.404753           0
# 6   CIN  8.152571  14.881670    23.034241           0
# 10  HOU  6.111719  14.783217    20.894936           1
# 0   ARI  7.495211  10.764706    18.259917           0
# 20  PHI  7.275618   3.680403    10.956020           0
# 5   CHW  6.395724   4.076917    10.472642           0
# 13  LAD  7.079536   2.961143    10.040678           0
# 9   DET  5.960382   2.000000     7.960382           0
# 23  SEA  7.665491   0.116090     7.781581           1
# 4   CHC  7.301517  -0.328873     6.972644           0
# 25  STL  6.124817   0.714457     6.839274           0
# 7   CLE  6.870044  -0.735200     6.134843           0
# 14  MIA  7.092962  -1.189873     5.903089           1
# 8   COL  6.083310  -2.000000     4.083310           1
# ...

# %%
## plot various distributions of offensive and defensive values

team_off_hist = px.histogram(team_df, x='OFF', nbins=50, title='Team Offensive Score Distribution', height=700, width=1000)
team_off_hist.show()

team_def_hist = px.histogram(team_df, x='DEF', nbins=50, title='Team Defensive Score Distribution', height=700, width=1000)
team_def_hist.show()

team_val_hist = px.histogram(team_df, x='Total Value', nbins=50, title='Team Total Value Distribution', height=700, width=1000)
team_val_hist.show()

# %%
## box plot of team total value
team_val_box = px.box(team_df, x='Total Value', title='Team Total Value Box Plot', color='is_full_DH', height=700, width=1000, points='all')
team_val_box.show()

# %%
data2 = pd.read_csv('allhitters.csv')
data2.head()
data2.columns
fig3 = px.histogram(data2, x='RBI', nbins=50, title='RBI Distribution', height=700, width=1000)
fig3.show()
data2.RBI.describe()
